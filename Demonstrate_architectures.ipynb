# %% [markdown]
# ## Import necessary libraries:

# %%
import tensorflow as tf
import keras as K 
tf.__version__, K.__version__
# Out:
# ('2.3.1', '2.4.3')

# %%
# load processing func
import source.toolkit as tk
import source.dojo_tools as dj 

from source.toolkit import list_channels
from source.toolkit import list_channels_df

# load main class object for monitoring blood cells
from source.SickleML_Monitor import CountAdheredBloodCells 

# Loading tools for extracting gdrive data 
import source.load_data_tools as loading_tools

import os
import time
import pandas as pd

import sys
import gdown

# %% [markdown]
# ## Download pretrained weights from gdrive:
#
# Important to note, if you haven't downloaded the pretrained weights (e.g Resnet50 and encoder-decoder model) in your working directory, you must run the below code. If you have already ran the main.ipynb notebook, you might already have the networks downloaded.
#
# Don't worry if it takes several minutes to load because there is several network weights to download. In addition, by default the remaining pretrained models found in the supplementary material is suppressed with quotations. You are also more then welcome the depress the comment quotations and download those weights onto your working directory. Overall, all of the pretrained weights will be saved in automatic folder called "./Phase2_Pretrained-models/*" or "./Phase1_Pretrained-models/*"

# %% [markdown]
# #### Phase I networks

# %%
' Download encoder-decoder weights '

os.makedirs(f'./Phase1_Pretrained-models/ce-jaccard_encoder-decoder-net/', exist_ok = True)
os.chdir(f'./Phase1_Pretrained-models/ce-jaccard_encoder-decoder-net/') 

loading_tools.ce_jaccard_gdrive_()
    
os.chdir(f'../')
os.chdir(f'../')


' Download hr-net weights '

os.makedirs(f'./Phase1_Pretrained-models/hrnet_ce-jaccard_hr-net/', exist_ok = True)
os.chdir(f'./Phase1_Pretrained-models/hrnet_ce-jaccard_hr-net/') 

loading_tools.hrnet_CeJaccard_gdrive_()

os.chdir(f'../')
os.chdir(f'../')
# Out:
# Start downloading encoder-decoder Ce-Jaccard net models...
# Downloading...
# From: https://drive.google.com/uc?id=1mtewaKMXqdIVmWj1mXKQfYK9Tr5OCD7J
# To: C:\Users\npral\OneDrive\Desktop\BiotheoryGroup\DeepLearning-SCDBiochip\Phase1_Pretrained-models\ce-jaccard_encoder-decoder-net\Phase1_Kfold-model_0.h5
# 63.5MB [00:19, 3.27MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1lQHqgcRCDhmAL5BrxSyfYwtejmpt_rXP
# To: C:\Users\npral\OneDrive\Desktop\BiotheoryGroup\DeepLearning-SCDBiochip\Phase1_Pretrained-models\ce-jaccard_encoder-decoder-net\Phase1_Kfold-model_0.json
# 100%|█████████████████████████████████████████████████████████████████████████████| 31.0k/31.0k [00:00<00:00, 3.78MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1K1cduESQHDozHZYInEE0PmREdvvahiRs
# To: C:\Users\npral\OneDrive\Desktop\BiotheoryGroup\DeepLearning-SCDBiochip\Phase1_Pretrained-models\ce-jaccard_encoder-decoder-net\Phase1_Kfold-model_1.h5
# 63.5MB [00:19, 3.22MB/s]
# Downloading...
# ...

# %% [markdown]
# ### Present Phase I architectures:

# %%
' Presenting the encoder-decoder model architecture'

filenames = os.listdir('./Phase1_Pretrained-models/ce-jaccard_encoder-decoder-net/')
filenames = [filenames[ii].replace('.h5','').replace('.json','') for ii in range(len(filenames))]
encoder_decoder_ensemble = tk.load_zoo('./Phase1_Pretrained-models/ce-jaccard_encoder-decoder-net/', filenames)
encoder_decoder_ensemble[0].summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 64) 1792        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 64) 256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 128, 128, 64) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# ...

# %%
' Presenting the hr-net model architecture'

filenames = os.listdir('./Phase1_Pretrained-models/hrnet_ce-jaccard_hr-net/')
filenames = [filenames[ii].replace('.h5','').replace('.json','') for ii in range(len(filenames))]
hrnet_ensemble = tk.load_zoo('./Phase1_Pretrained-models/hrnet_ce-jaccard_hr-net/', filenames)
hrnet_ensemble[0].summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 64)   1728        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 64, 64, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# ## Present Phase II architectures:

# %% [markdown]
# You might already have the models below download from gdrive to your working directory. If so, skip the below code and jump straight to

# %%
"""

' Download Resnet50 pretrained weights '

os.makedirs(f'./Phase2_Pretrained-models/Resnet50/', exist_ok = True)
os.chdir(f'./Phase2_Pretrained-models/Resnet50/') 

loading_tools.resnet50_gdrive_()
    
os.chdir(f'../')
os.chdir(f'../')



' Download Vanilla pretrained weights '

os.makedirs(f'./Phase2_Pretrained-models/Vanilla/', exist_ok = True)
os.chdir(f'./Phase2_Pretrained-models/Vanilla/') 

loading_tools.Vanilla_gdrive_()

os.chdir(f'../')
os.chdir(f'../')
"""
' Download Xception pretrained weights '

os.makedirs(f'./Phase2_Pretrained-models/Xception/', exist_ok = True)
os.chdir(f'./Phase2_Pretrained-models/Xception/') 

loading_tools.Xception_gdrive_()

os.chdir(f'../')
os.chdir(f'../')
# Out:
# Start downloading Xception net models...

# %% [markdown]
# #### Phase II architectures

# %%
' Presenting the fine-tuned Resnet50 model architecture'

filenames = os.listdir('./Phase2_Pretrained-models/Resnet50/')
filenames = [filenames[ii].replace('.h5','').replace('.json','') for ii in range(len(filenames))]
Resnet50_ensemble = tk.load_zoo('./Phase2_Pretrained-models/Resnet50/', filenames)
Resnet50_ensemble[0].summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# FlobalGlobal_avg (GlobalAver (None, 2048)              0
# _________________________________________________________________
# sRBC_classes (Dense)         (None, 3)                 6147
# ...
# Total params: 23,593,859
# Trainable params: 23,540,739
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
' Presenting the fine-tuned Vanilla model architecture'

filenames = os.listdir('./Phase2_Pretrained-models/Vanilla/')
filenames = [filenames[ii].replace('.h5','').replace('.json','') for ii in range(len(filenames))]
Vanilla_ensemble = tk.load_zoo('./Phase2_Pretrained-models/Vanilla/', filenames)
Vanilla_ensemble[0].summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lower_head (Functional)      (None, 8, 8, 64)          19392
# _________________________________________________________________
# FlobalGlobal_avg (GlobalAver (None, 64)                0
# _________________________________________________________________
# sRBC_classes (Dense)         (None, 3)                 195
# ...
# Total params: 19,587
# Trainable params: 19,587
# Non-trainable params: 0
# _________________________________________________________________

# %%
' Presenting the fine-tuned Xception model architecture'

filenames = os.listdir('./Phase2_Pretrained-models/Xception/')
filenames = [filenames[ii].replace('.h5','').replace('.json','') for ii in range(len(filenames))]
Xception_ensemble = tk.load_zoo('./Phase2_Pretrained-models/Xception/', filenames)
Xception_ensemble[0].summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# xception (Functional)        (None, 7, 7, 2048)        20861480
# _________________________________________________________________
# FlobalGlobal_avg (GlobalAver (None, 2048)              0
# _________________________________________________________________
# sRBC_classes (Dense)         (None, 3)                 6147
# ...
# Total params: 20,867,627
# Trainable params: 20,813,099
# Non-trainable params: 54,528
# _________________________________________________________________
